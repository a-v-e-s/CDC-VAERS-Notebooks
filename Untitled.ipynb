# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os

# %%
# %matplotlib inline

# %%
os.chdir('/home/aves/Documents/VAERS/')
# !ls *.csv
# Out:
# 2021VAERSDATA.csv  2021VAERSSYMPTOMS.csv  2021VAERSVAX.csv

# %%
with open('2021VAERSDATA.csv', 'rb') as f:
    line1 = f.readline()

print(line1)
# Out:
# b'VAERS_ID,RECVDATE,STATE,AGE_YRS,CAGE_YR,CAGE_MO,SEX,RPT_DATE,SYMPTOM_TEXT,DIED,DATEDIED,L_THREAT,ER_VISIT,HOSPITAL,HOSPDAYS,X_STAY,DISABLE,RECOVD,VAX_DATE,ONSET_DATE,NUMDAYS,LAB_DATA,V_ADMINBY,V_FUNDBY,OTHER_MEDS,CUR_ILL,HISTORY,PRIOR_VAX,SPLTTYPE,FORM_VERS,TODAYS_DATE,BIRTH_DEFECT,OFC_VISIT,ER_ED_VISIT,ALLERGIES\r\n'

# %%
VAERS_DATA = pd.read_csv('2021VAERSDATA.csv', encoding='cp1252')
VAERS_SYMPTOMS = pd.read_csv('2021VAERSSYMPTOMS.csv', encoding='cp1252')
VAERS_VAX = pd.read_csv('2021VAERSVAX.csv', encoding='cp1252')

# %%
print('VAERS_DATA:'); print()
print('Columns:', VAERS_DATA.columns); print()
print('Shape:', VAERS_DATA.shape)
VAERS_DATA.head(6)
# Out:
# VAERS_DATA:
#
# Columns: Index(['VAERS_ID', 'RECVDATE', 'STATE', 'AGE_YRS', 'CAGE_YR', 'CAGE_MO', 'SEX',
#        'RPT_DATE', 'SYMPTOM_TEXT', 'DIED', 'DATEDIED', 'L_THREAT', 'ER_VISIT',
#        'HOSPITAL', 'HOSPDAYS', 'X_STAY', 'DISABLE', 'RECOVD', 'VAX_DATE',
#        'ONSET_DATE', 'NUMDAYS', 'LAB_DATA', 'V_ADMINBY', 'V_FUNDBY',
#        'OTHER_MEDS', 'CUR_ILL', 'HISTORY', 'PRIOR_VAX', 'SPLTTYPE',
#        'FORM_VERS', 'TODAYS_DATE', 'BIRTH_DEFECT', 'OFC_VISIT', 'ER_ED_VISIT',
#        'ALLERGIES'],
#       dtype='object')
#
# Shape: (418781, 35)
#    VAERS_ID    RECVDATE STATE  AGE_YRS  CAGE_YR  CAGE_MO SEX RPT_DATE  \
# 0    916600  01/01/2021    TX     33.0     33.0      NaN   F      NaN
# 1    916601  01/01/2021    CA     73.0     73.0      NaN   F      NaN
# 2    916602  01/01/2021    WA     23.0     23.0      NaN   F      NaN
# 3    916603  01/01/2021    WA     58.0     58.0      NaN   F      NaN
# 4    916604  01/01/2021    TX     47.0     47.0      NaN   F      NaN
# ...

# %%
print(VAERS_DATA['DIED'].unique())
print(VAERS_DATA['ER_VISIT'].unique())
print(VAERS_DATA['DISABLE'].unique())
# Out:
# [nan 'Y']
# [nan 'Y']
# [nan 'Y']

# %%
DIED_DF = VAERS_DATA[VAERS_DATA['DIED']=='Y']
DEATH_IDS = DIED_DF['VAERS_ID']

ER_VISIT_DF = VAERS_DATA[VAERS_DATA['ER_VISIT']=='Y']
ER_VISIT_IDS = ER_VISIT_DF['VAERS_ID']

DISABLE_DF = VAERS_DATA[VAERS_DATA['DISABLE']=='Y']
DISABLE_IDS = DISABLE_DF['VAERS_ID']
#print('type(ob):', type(ob))
#print('dir(ob):', dir(ob))

# %%
print('number of deaths:', len(DEATH_IDS))
print('number of er visits:', len(ER_VISIT_IDS))
print('number of disabilities:', len(DISABLE_IDS))
# Out:
# number of deaths: 5626
# number of er visits: 51
# number of disabilities: 6295

# %%
print('VAERS_SYMPTOMS:'); print()
print('Columns:', VAERS_SYMPTOMS.columns); print()
print('Shape:', VAERS_SYMPTOMS.shape); print()
VAERS_SYMPTOMS.head(6)
# Out:
# VAERS_SYMPTOMS:
#
# Columns: Index(['VAERS_ID', 'SYMPTOM1', 'SYMPTOMVERSION1', 'SYMPTOM2',
#        'SYMPTOMVERSION2', 'SYMPTOM3', 'SYMPTOMVERSION3', 'SYMPTOM4',
#        'SYMPTOMVERSION4', 'SYMPTOM5', 'SYMPTOMVERSION5'],
#       dtype='object')
#
# Shape: (561558, 11)
#    VAERS_ID                 SYMPTOM1  SYMPTOMVERSION1  \
# 0    916600                Dysphagia             23.1
# 1    916601                  Anxiety             23.1
# 2    916602         Chest discomfort             23.1
# 3    916603                Dizziness             23.1
# 4    916604  Injection site erythema             23.1
# 5    916605                   Chills             24.0
#
#                   SYMPTOM2  SYMPTOMVERSION2                 SYMPTOM3  \
# 0             Epiglottitis             23.1                      NaN
# 1                 Dyspnoea             23.1                      NaN
# 2                Dysphagia             23.1        Pain in extremity
# ...

# %%
print(len(VAERS_SYMPTOMS['SYMPTOM1'].unique()))
print(len(VAERS_SYMPTOMS['SYMPTOM2'].unique()))
print(len(VAERS_SYMPTOMS['SYMPTOM3'].unique()))
print(len(VAERS_SYMPTOMS['SYMPTOM4'].unique()))
print(len(VAERS_SYMPTOMS['SYMPTOM5'].unique()))
# Out:
# 5942
# 5705
# 5253
# 4754
# 4384

# %%
print('VAERS_VAX:'); print()
print('Columns:', VAERS_VAX.columns); print()
print('Shape:', VAERS_VAX.shape); print()
VAERS_VAX.head(6)
# Out:
# VAERS_VAX:
#
# Columns: Index(['VAERS_ID', 'VAX_TYPE', 'VAX_MANU', 'VAX_LOT', 'VAX_DOSE_SERIES',
#        'VAX_ROUTE', 'VAX_SITE', 'VAX_NAME'],
#       dtype='object')
#
# Shape: (434899, 8)
#    VAERS_ID VAX_TYPE         VAX_MANU  VAX_LOT VAX_DOSE_SERIES VAX_ROUTE  \
# 0    916600  COVID19          MODERNA  037K20A               1        IM
# 1    916601  COVID19          MODERNA  025L20A               1        IM
# 2    916602  COVID19  PFIZER\BIONTECH   EL1284               1        IM
# 3    916603  COVID19          MODERNA  unknown             UNK       NaN
# 4    916604  COVID19          MODERNA      NaN               1        IM
# 5    916605    FLUC4    SEQIRUS, INC.   276563               1       SYR
#
#   VAX_SITE                                       VAX_NAME
# 0       LA                    COVID19 (COVID19 (MODERNA))
# 1       RA                    COVID19 (COVID19 (MODERNA))
# 2       LA            COVID19 (COVID19 (PFIZER-BIONTECH))
# ...

# %%
print('type(VAERS_DATA):')
print(type(VAERS_DATA))
print()
print('dir(VAERS_DATA):')
dir(VAERS_DATA)
# Out:
# type(VAERS_DATA):
# <class 'pandas.core.frame.DataFrame'>
#
# dir(VAERS_DATA):
# ['AGE_YRS',
#  'ALLERGIES',
#  'BIRTH_DEFECT',
#  'CAGE_MO',
#  'CAGE_YR',
#  'CUR_ILL',
#  'DATEDIED',
#  'DIED',
#  'DISABLE',
#  'ER_ED_VISIT',
#  'ER_VISIT',
#  'FORM_VERS',
#  'HISTORY',
#  'HOSPDAYS',
#  'HOSPITAL',
#  'LAB_DATA',
#  'L_THREAT',
#  'NUMDAYS',
#  'OFC_VISIT',
#  'ONSET_DATE',
#  'OTHER_MEDS',
#  'PRIOR_VAX',
#  'RECOVD',
#  'RECVDATE',
#  'RPT_DATE',
#  'SEX',
#  'SPLTTYPE',
#  'STATE',
#  'SYMPTOM_TEXT',
#  'T',
#  'TODAYS_DATE',
#  'VAERS_ID',
#  'VAX_DATE',
#  'V_ADMINBY',
#  'V_FUNDBY',
#  'X_STAY',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
# ...
